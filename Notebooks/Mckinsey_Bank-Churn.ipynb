# %% [markdown]
# ## CHURN - USE CASE

# %% [markdown]
# ### Load libraries and functions

# %%
import numpy as np
import pandas as pd
import random
import os
import datetime
from collections import Counter

# Split Dataset into Train- Test
from sklearn.model_selection import train_test_split

# Machine Learning Models
import xgboost as xgb
from sklearn.linear_model import LogisticRegression

# Performance Metrics
from sklearn.metrics import confusion_matrix

# %% [markdown]
# - [1.- Data](#section1)
#     + [1.1.- Read Data](#section1.1)
#     + [1.2.- Discuss and prepare target variable](#section1.2)
#     + [1.3.- Create additional variables](#section1.3)
#
# - [2.- Model](#section2)
#     + [2.1.- Logistic Regression](#section2.1)
#     + [2.2.- XGBoost](#section2.2)
#     + [2.3.- Evaluation of Models](#section2.3)

# %%
# Load auxiliar metrics functions
from aux_metrics import get_uplift, get_feature_importance # you should have this script in the same folder as the notebook

# %%
# Set seed for reproducibility
random.seed(42)

# Set data path
project_path = './' # path to indicate where your file is saved in your local computer
# You can put the full path or the relative path, ./ is the same folder as where the notebook is located

# %% [markdown]
# <a id='section1'></a>
# ## STEP 1: Data

# %% [markdown]
# <a id='section1.1'></a>
# ### Read Data

# %%
churn_file_name = "bankingchurn_data_modif.csv"
df_churn = pd.read_csv(
    project_path + churn_file_name, 
    na_values=['-'], 
    sep = ';', # the separator between columns is ;, it can be checked in notepad
    decimal = ',' # to make sure pandas understands that the , is used as decimal seprator and reads numeric columns as numeric
)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Data dimensions (#rows, #columns)
df_churn.shape
# Out:
# (100000, 44)

# %%
# Make quick cross-checks
df_churn.head()
# Out:
#   contract_start contract_end date_of_birth gender             profession  \
# 0     2010-10-24          NaN    1991-02-11      M  Professional Services
# 1     2010-04-30   2017-10-20    1986-04-06      W                    NaN
# 2     2013-05-02          NaN    1993-04-18      M         Transportation
# 3     2016-12-24          NaN    1994-07-29      W  Professional Services
# 4     2011-10-01          NaN    1990-10-28      W               Research
#
#    size_household    ZIP segment  credit_rating  no_credit_rating_flag  \
# 0               1  76829      S2      89.568518                      0
# 1               1  35104      S2      94.270507                      0
# 2               1  63450      S2      93.030947                      0
# 3               2   9573      S3            NaN                      1
# 4               1  66916      S2      90.457664                      0
#
#           ...          online_number_of_logins_per_month  \
# 0         ...                                          0
# 1         ...                                         16
# 2         ...                                         26
# 3         ...                                          0
# 4         ...                                         23
#
#    online_tranactions_per_month  advisor_contacts_last12months  \
# 0                             0                              3
# 1                             8                              2
# 2                            12                              2
# 3                             0                              4
# 4                            18                              3
#
#    customer_limit  cash_withdraws_per_month  cash_withdrawals_value  \
# 0          1000.0                         4              459.840940
# 1          1000.0                         7              476.334459
# 2          1000.0                         3              332.640202
# 3          1050.0                         4              378.324744
# 4          1000.0                         4              471.509299
#
#    consumer_credit_value  consumer_credit_maturity  account_fee  \
# 0          -24011.393552                       205           15
# 1           -5368.743068                       137           15
# 2           -9678.713419                       624           15
# 3          -12110.305916                      1263           10
# 4               0.000000                       521           10
#
#    number_of_refusals
# 0                   6
# 1                   6
# 2                   4
# 3                   7
# 4                   3
#
# [5 rows x 44 columns]

# %%
df_churn.head().T
# Out:
#                                                        0           1  \
# contract_start                                2010-10-24  2010-04-30
# contract_end                                         NaN  2017-10-20
# date_of_birth                                 1991-02-11  1986-04-06
# gender                                                 M           W
# profession                         Professional Services         NaN
# size_household                                         1           1
# ZIP                                                76829       35104
# segment                                               S2          S2
# credit_rating                                    89.5685     94.2705
# no_credit_rating_flag                                  0           0
# main_account_flag                                      0           0
# online_banking_flag                                    0           1
# tele_banking_flag                                      1           1
# creditcard_flag                                        0           1
# insurance_life_flag                                    0           0
# insurance_house_flag                                   1           1
# insurance_car_flag                                     1           1
# insurance_other_flag                                   1           0
# mortgage_flag                                          1           1
# portfolio_flag                                         0           0
# last_balance                                     38694.4     77759.1
# last_balance_minus_6_months                      57898.1     67914.7
# last_balance_minus_12_months                     57993.5     55263.3
# income_salary_per_year                                 0           0
# income_deposits_per_year                               0           0
# income_securities_per_year                             0           0
# insurance_life_premium_per_month                       0           0
# insurance_house_premium_per_year                       0           0
# insurance_car_premium_per_year                         0           0
# mortgage_value                                         0           0
# mortgage_interest                                      0           0
# mortgage_downpayment                                   0           0
# mortgage_dayuntilmaturity                              0           0
# mortgage_numbers                                       0           0
# online_number_of_logins_per_month                      0          16
# online_tranactions_per_month                           0           8
# advisor_contacts_last12months                          3           2
# customer_limit                                      1000        1000
# cash_withdraws_per_month                               4           7
# cash_withdrawals_value                           459.841     476.334
# consumer_credit_value                           -24011.4    -5368.74
# consumer_credit_maturity                             205         137
# account_fee                                           15          15
# number_of_refusals                                     6           6
#
#                                                 2                      3  \
# contract_start                         2013-05-02             2016-12-24
# contract_end                                  NaN                    NaN
# date_of_birth                          1993-04-18             1994-07-29
# gender                                          M                      W
# profession                         Transportation  Professional Services
# size_household                                  1                      2
# ZIP                                         63450                   9573
# segment                                        S2                     S3
# credit_rating                             93.0309                    NaN
# no_credit_rating_flag                           0                      1
# main_account_flag                               0                      1
# online_banking_flag                             1                      0
# tele_banking_flag                               0                      0
# creditcard_flag                                 1                      1
# insurance_life_flag                             0                      0
# insurance_house_flag                            1                      1
# insurance_car_flag                              1                      1
# insurance_other_flag                            0                      1
# mortgage_flag                                   1                      0
# portfolio_flag                                  0                      0
# last_balance                                46702                10917.8
# last_balance_minus_6_months               52687.3                9506.82
# last_balance_minus_12_months              56011.6                12194.7
# income_salary_per_year                          0                      0
# income_deposits_per_year                        0                      0
# income_securities_per_year                      0                      0
# insurance_life_premium_per_month                0                      0
# insurance_house_premium_per_year                0                486.581
# insurance_car_premium_per_year                  0                335.885
# mortgage_value                                  0                      0
# mortgage_interest                               0                      0
# mortgage_downpayment                            0                      0
# mortgage_dayuntilmaturity                       0                    104
# mortgage_numbers                                0                      0
# online_number_of_logins_per_month              26                      0
# online_tranactions_per_month                   12                      0
# advisor_contacts_last12months                   2                      4
# customer_limit                               1000                   1050
# cash_withdraws_per_month                        3                      4
# cash_withdrawals_value                     332.64                378.325
# consumer_credit_value                    -9678.71               -12110.3
# consumer_credit_maturity                      624                   1263
# account_fee                                    15                     10
# number_of_refusals                              4                      7
#
#                                             4
# contract_start                     2011-10-01
# contract_end                              NaN
# date_of_birth                      1990-10-28
# gender                                      W
# profession                           Research
# size_household                              1
# ZIP                                     66916
# segment                                    S2
# credit_rating                         90.4577
# no_credit_rating_flag                       0
# main_account_flag                           0
# online_banking_flag                         1
# tele_banking_flag                           0
# creditcard_flag                             1
# insurance_life_flag                         0
# insurance_house_flag                        1
# insurance_car_flag                          1
# insurance_other_flag                        0
# mortgage_flag                               0
# portfolio_flag                              0
# last_balance                          26170.4
# last_balance_minus_6_months           29474.1
# last_balance_minus_12_months            16831
# income_salary_per_year                      0
# income_deposits_per_year                    0
# income_securities_per_year                  0
# insurance_life_premium_per_month            0
# insurance_house_premium_per_year            0
# insurance_car_premium_per_year              0
# mortgage_value                              0
# mortgage_interest                           0
# mortgage_downpayment                        0
# mortgage_dayuntilmaturity                   0
# mortgage_numbers                            0
# online_number_of_logins_per_month          23
# online_tranactions_per_month               18
# advisor_contacts_last12months               3
# customer_limit                           1000
# cash_withdraws_per_month                    4
# cash_withdrawals_value                471.509
# consumer_credit_value                       0
# consumer_credit_maturity                  521
# account_fee                                10
# number_of_refusals                          3

# %%
# Statistical Information: .describe()
df_churn.describe()
# Out:
#        size_household  credit_rating  no_credit_rating_flag  \
# count   100000.000000   77517.000000          100000.000000
# mean         1.665850      91.480805               0.224830
# std          0.793788       5.668550               0.417472
# min          1.000000      43.720633               0.000000
# 25%          1.000000      88.680536               0.000000
# 50%          1.000000      92.778025               0.000000
# 75%          2.000000      95.653020               0.000000
# max          6.000000      99.495558               1.000000
#
#        main_account_flag  online_banking_flag  tele_banking_flag  \
# count       100000.00000        100000.000000       100000.00000
# mean             0.48612             0.729260            0.35982
# std              0.49981             0.444344            0.47995
# min              0.00000             0.000000            0.00000
# 25%              0.00000             0.000000            0.00000
# 50%              0.00000             1.000000            0.00000
# 75%              1.00000             1.000000            1.00000
# max              1.00000             1.000000            1.00000
#
#        creditcard_flag  insurance_life_flag  insurance_house_flag  \
# count    100000.000000        100000.000000         100000.000000
# mean          0.479610             0.222810              1.076250
# std           0.499587             0.416134              0.265399
# min           0.000000             0.000000              1.000000
# 25%           0.000000             0.000000              1.000000
# 50%           0.000000             0.000000              1.000000
# 75%           1.000000             0.000000              1.000000
# max           1.000000             1.000000              2.000000
#
#        insurance_car_flag         ...          \
# count       100000.000000         ...
# mean             0.710510         ...
# std              0.453528         ...
# min              0.000000         ...
# 25%              0.000000         ...
# 50%              1.000000         ...
# 75%              1.000000         ...
# max              1.000000         ...
#
#        online_number_of_logins_per_month  online_tranactions_per_month  \
# count                      100000.000000                  100000.00000
# mean                           14.194810                       9.18393
# std                            12.112868                      10.04345
# min                             0.000000                       0.00000
# 25%                             0.000000                       0.00000
# 50%                            15.000000                       6.00000
# 75%                            24.000000                      16.00000
# max                            67.000000                      59.00000
#
#        advisor_contacts_last12months  customer_limit  \
# count                  100000.000000   100000.000000
# mean                        1.654470     1287.443365
# std                         1.807432      512.328403
# min                         0.000000       50.000000
# 25%                         0.000000     1000.000000
# 50%                         1.000000     1000.000000
# 75%                         3.000000     1500.000000
# max                         6.000000     4800.000000
#
#        cash_withdraws_per_month  cash_withdrawals_value  \
# count             100000.000000           100000.000000
# mean                   4.036680              300.769580
# std                    1.716183              189.729464
# min                    0.000000                0.000000
# 25%                    3.000000              154.226137
# 50%                    4.000000              295.055682
# 75%                    5.000000              431.438064
# max                    8.000000             1172.363497
#
#        consumer_credit_value  consumer_credit_maturity   account_fee  \
# count          100000.000000             100000.000000  100000.00000
# mean            -3394.078264                456.426170      10.51490
# std              5959.513473                485.093374       6.09149
# min            -43213.432348                  0.000000       0.00000
# 25%             -5075.175558                  0.000000      10.00000
# 50%                 0.000000                302.000000      10.00000
# 75%                 0.000000                858.000000      15.00000
# max                 0.000000               3003.000000      20.00000
#
#        number_of_refusals
# count       100000.000000
# mean             5.043130
# std              4.241062
# min              0.000000
# 25%              1.000000
# 50%              5.000000
# 75%              8.000000
# max             31.000000
#
# [8 rows x 37 columns]

# %%
# Info about nulls: .info()
print(df_churn.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 44 columns):
# contract_start                       100000 non-null object
# contract_end                         4871 non-null object
# date_of_birth                        100000 non-null object
# gender                               100000 non-null object
# profession                           92271 non-null object
# size_household                       100000 non-null int64
# ZIP                                  100000 non-null object
# segment                              100000 non-null object
# credit_rating                        77517 non-null float64
# no_credit_rating_flag                100000 non-null int64
# main_account_flag                    100000 non-null int64
# online_banking_flag                  100000 non-null int64
# tele_banking_flag                    100000 non-null int64
# creditcard_flag                      100000 non-null int64
# insurance_life_flag                  100000 non-null int64
# insurance_house_flag                 100000 non-null int64
# insurance_car_flag                   100000 non-null int64
# insurance_other_flag                 100000 non-null int64
# mortgage_flag                        100000 non-null int64
# portfolio_flag                       100000 non-null int64
# last_balance                         100000 non-null float64
# last_balance_minus_6_months          100000 non-null float64
# last_balance_minus_12_months         100000 non-null float64
# income_salary_per_year               100000 non-null float64
# income_deposits_per_year             100000 non-null float64
# income_securities_per_year           100000 non-null float64
# insurance_life_premium_per_month     100000 non-null float64
# insurance_house_premium_per_year     100000 non-null float64
# insurance_car_premium_per_year       100000 non-null float64
# mortgage_value                       100000 non-null float64
# mortgage_interest                    100000 non-null float64
# mortgage_downpayment                 100000 non-null float64
# mortgage_dayuntilmaturity            100000 non-null int64
# mortgage_numbers                     100000 non-null int64
# online_number_of_logins_per_month    100000 non-null int64
# online_tranactions_per_month         100000 non-null int64
# advisor_contacts_last12months        100000 non-null int64
# customer_limit                       100000 non-null float64
# cash_withdraws_per_month             100000 non-null int64
# cash_withdrawals_value               100000 non-null float64
# consumer_credit_value                100000 non-null float64
# consumer_credit_maturity             100000 non-null int64
# account_fee                          100000 non-null int64
# number_of_refusals                   100000 non-null int64
# dtypes: float64(16), int64(21), object(7)
# memory usage: 33.6+ MB
# None

# %%
print(Counter(df_churn.dtypes))
# Out:
# Counter({dtype('int64'): 21, dtype('float64'): 16, dtype('O'): 7})

# %%
for col in df_churn.columns: 
    print(col, df_churn[col].nunique())
# Out:
# contract_start 8232
# contract_end 365
# date_of_birth 14842
# gender 2
# profession 48
# size_household 6
# ZIP 16055
# segment 5
# credit_rating 77517
# no_credit_rating_flag 2
# main_account_flag 2
# online_banking_flag 2
# tele_banking_flag 2
# creditcard_flag 2
# insurance_life_flag 2
# insurance_house_flag 2
# insurance_car_flag 2
# insurance_other_flag 2
# mortgage_flag 2
# portfolio_flag 2
# last_balance 100000
# last_balance_minus_6_months 100000
# last_balance_minus_12_months 100000
# income_salary_per_year 37003
# income_deposits_per_year 19340
# income_securities_per_year 19346
# insurance_life_premium_per_month 10809
# insurance_house_premium_per_year 45150
# insurance_car_premium_per_year 34535
# mortgage_value 16677
# mortgage_interest 20779
# mortgage_downpayment 20795
# mortgage_dayuntilmaturity 8589
# mortgage_numbers 4
# online_number_of_logins_per_month 62
# online_tranactions_per_month 57
# advisor_contacts_last12months 7
# customer_limit 9833
# cash_withdraws_per_month 9
# cash_withdrawals_value 93358
# consumer_credit_value 36993
# consumer_credit_maturity 1970
# account_fee 4
# number_of_refusals 26

# %% [markdown]
# <a id='section1.2'></a>
# ### Discuss and prepare target variable

# %%
## Task 1b: Create target, 1 means churn 0 means no churn
df_churn["target"] = np.where(df_churn['contract_end'].isna(), 0,1)

# %%
# Check distribution of the target variable
df_churn.groupby('target').size()/df_churn.shape[0]
# Out:
# target
# 0    0.95129
# 1    0.04871
# dtype: float64

# %% [markdown]
# <a id='section1.3'></a>
# ### Create Additional Variables

# %%
df_churn['age'] = (pd.Timestamp.today() - \
                   pd.to_datetime(df_churn['date_of_birth']))/np.timedelta64(1, 'Y')
df_churn[['contract_start', 'date_of_birth', 'age']].head()
# Out:
#   contract_start date_of_birth        age
# 0     2010-10-24    1991-02-11  28.692717
# 1     2010-04-30    1986-04-06  33.544289
# 2     2013-05-02    1993-04-18  26.510605
# 3     2016-12-24    1994-07-29  25.232003
# 4     2011-10-01    1990-10-28  28.982935

# %%
# remove variables not needed (dates, helper veriables, row index...)
df_churn = df_churn.drop(['contract_start', 'contract_end',  'date_of_birth', 'ZIP'], axis = 1)

# %%
# Missing data imputation - Replace each missing value with an own category, e.g. "NA -> Not_available"
df_churn.loc[df_churn['profession'].isna(), 'profession'] = 'unknown'

# %% [markdown]
# <a id='section2'></a>
# ### STEP 2: MODEL

# %% [markdown]
# - Separate the dataset into train - dev - test
# - Build a model
# - Obtain model performance

# %% [markdown]
# <a id='section2.1'></a>
# ### Logistic Regression

# %%
# Option 1: Logistic regression with manual variable selection

logit_model = LogisticRegression()
var_select  = ["size_household", 
               "income_deposits_per_year", 
               "main_account_flag", 
               "insurance_house_premium_per_year", 
               "income_securities_per_year", 
               "cash_withdraws_per_month"]

# %%
# Split data: leave out evaluation set

# X: explanatory variables, y: target
X = df_churn[var_select]
y = df_churn['target']

    # 1. Train (train + test), evaluation
x_train, x_eval_logit, y_train, y_eval_logit = train_test_split(X, y, test_size=0.2)

    # 2. Split training data again into training and test set
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# 2.1. Training set: fit the model
logit_model.fit(x_train,y_train)

# 2.2. Test set: 
# Predictions
predictions_logreg = logit_model.predict(x_test)

# Check accuracy of predictions
accuracy_logreg = confusion_matrix(y_test.values, predictions_logreg)

print(sum(np.diagonal(accuracy_logreg))/sum(sum(accuracy_logreg)))
print(accuracy_logreg)
print(get_uplift(predictions_logreg, y_test.values)[['percentile','acc_uplift']].head())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9519375
# [[15231    12]
#  [  757     0]]
#         percentile  acc_uplift
# n_tile
# 1.0              1    0.000000
# 2.0              2    0.000000
# 3.0              3    0.000000
# 4.0              4    0.000000
# 5.0              5    1.666667
# C:\Users\Vuk Vuksanovic\Documents\_recruiting\analytics\20191016_upm_event\aux_metrics.py:21: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   uplift_result = uplift_df.groupby(["n_tile"])["y_true"].agg({'num_observations':'count','num_positives':"sum", "segment_precision":"mean"})

# %% [markdown]
# <a id='section2.2'></a>
# ### XGBoost

# %%
# Option 2: Xgboost without variable selection (all numerical variables are included)

# Specify the kind of model to develop
xgb_reg = xgb.XGBRegressor(objective ='binary:logistic', 
                          colsample_bytree = 0.3, 
                          learning_rate = 0.1,
                          max_depth = 5, 
                          n_estimators = 350)

# %%
# Split data: leave out evaluation set
    # Variable selection: return columns in df_churn.columns that are not in []
var_select = np.setdiff1d(df_churn.columns, ['target', 'profession', 'segment'])

    # X: explanatory variables, y: target
x_train = df_churn[var_select].apply(pd.to_numeric, errors='coerce')
y_train = df_churn['target']

    # 1. Train (train + test), evaluation
x_train, x_eval_xgb, y_train, y_eval_xgb = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

    # 2. Split training data again into training and test set
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# 2.1. Training set: fit the model
xgb_reg.fit(x_train, y_train)

# 2.2. Test set: 
# Predictions
preds = xgb_reg.predict(x_test)

# Check accuracy of predictions
accuracy_xgb = confusion_matrix(y_test.values, np.round(preds))
    
print(sum(np.diagonal(accuracy_xgb))/sum(sum(accuracy_xgb)))
print(accuracy_xgb)
# Out:
# 0.9696875
# [[15144    50]
#  [  435   371]]

# %%
# Obtain the most important variables
scores_xgb = xgb_reg.get_booster().get_score(importance_type='gain')

most_imp_xgb = pd.DataFrame({'feature':list(scores_xgb.keys()), 'gain':list(scores_xgb.values())}).sort_values(by = ['gain'], ascending = False)
most_imp_xgb['gain'] = most_imp_xgb['gain']/most_imp_xgb['gain'].sum()
most_impt_xgb = most_imp_xgb.reset_index().drop('index', axis =1)
print(most_imp_xgb.head())
# Out:
#                             feature      gain
# 7                    size_household  0.094653
# 9          income_deposits_per_year  0.071581
# 0  insurance_house_premium_per_year  0.064344
# 4        income_securities_per_year  0.062961
# 1               online_banking_flag  0.059390

# %% [markdown]
# <a id='section2.3'></a>
# ### Evaluation of Models

# %%
# Evaluation of your model (TASK 4)---------------------------------------------------------------
# Evaluate your best model on the top decile of the evaluation dataset

# Option 1: Linear regression 

# Validation set:
# Predictions
preds_eval_logit  = logit_model.predict(x_eval_logit)
# Performance Metrics
accuracy_logit_eval = confusion_matrix(y_eval_logit.values, preds_eval_logit)
print(sum(np.diagonal(accuracy_logit_eval))/sum(sum(accuracy_logit_eval)))
print(get_uplift(preds_eval_logit, y_eval_logit.values)[['percentile','acc_uplift']].head())

# Option 2: Xgboost

# Validation set
# Predictions
preds_eval_xgb = xgb_reg.predict(x_eval_xgb)

# Performance Metrics
accuracy_xgb_eval = confusion_matrix(y_eval_xgb.values, np.round(preds_eval_xgb))
sum(np.diagonal(accuracy_xgb_eval))/sum(sum(accuracy_xgb_eval))
print(get_uplift(preds_eval_xgb, y_eval_xgb.values)[['percentile','acc_uplift']].head())
# Out:
# 0.9509
#         percentile  acc_uplift
# n_tile
# 1.0              1         0.0
# 2.0              2         0.0
# 3.0              3         0.0
# 4.0              4         0.0
# 5.0              5         0.0
# C:\Users\Vuk Vuksanovic\Documents\_recruiting\analytics\20191016_upm_event\aux_metrics.py:21: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   uplift_result = uplift_df.groupby(["n_tile"])["y_true"].agg({'num_observations':'count','num_positives':"sum", "segment_precision":"mean"})
#         percentile  acc_uplift
# n_tile
# 1.0              1   11.563523
# 2.0              2   11.043258
# 3.0              3   11.244218
# 4.0              4   11.213637
# 5.0              5   10.966897
